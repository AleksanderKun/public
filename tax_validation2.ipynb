# %% [markdown]
# # Polish Crypto Tax Engine Validation
#
# This notebook validates the `src.tax` module and runs targeted tests for Polish crypto tax calculation logic using the existing project code.

# %%
import sys
from pathlib import Path
repo_root = Path(r"C:/Users/Aleksander/.vscode/repository/public")
sys.path.insert(0, str(repo_root / 'src'))
print('repo_root', repo_root)
print('sys.path[0]', sys.path[0])

# %%
import src.tax.processor as processor
print('imported', processor.CryptoTaxCalculator)
# Out:
# imported <class 'src.tax.processor.CryptoTaxCalculator'>
